# %% [markdown]
# # Using VAETIMEGAN TB3M as covariate

# %%
import pandas as pd
import numpy as np
import itertools
from sklearn.metrics import mean_squared_error, mean_absolute_percentage_error, r2_score
import importlib
import tensorflow as tf
from tensorflow.keras import backend as K
import my_lstm
importlib.reload(my_lstm)
import gc

from my_lstm import build_lstm_model, create_sequences, expanding_window_lstm_forecast

# %%
df = pd.read_csv('../data/final_data_with_VAETIMEGAN.csv')
df['Date'] = pd.to_datetime(df['Date'])
df.head()
# Out:
#         Date  AUD_USD_ret  CAD_USD_ret  NZD_USD_ret  ZAR_USD_ret       CPI  \
# 0 1958-03-01     0.012299    -0.002406    -0.006743    -0.023616 -0.005484
# 1 1958-04-01     0.020833    -0.009353     0.060724     0.005213 -0.003673
# 2 1958-05-01     0.006006    -0.008792     0.009556     0.067115  0.002756
# 3 1958-06-01    -0.054147     0.010266    -0.037406     0.144931  0.003663
# 4 1958-07-01    -0.090823    -0.006553    -0.026149     0.010176  0.000914
#
#       TB3MS        M1        M2   wti_ret
# 0 -0.073454  0.013188  0.008006 -0.203766
# 1 -0.079281  0.011769  0.009704  0.018075
# 2  0.014742  0.017015  0.010501  0.180503
# 3  0.009709  0.013104  0.007785 -0.135577
# 4 -0.063144  0.014577  0.008258 -0.147348

# %%
feature_cols = [
    "TB3MS",
    "wti_ret"
]

target_col = "wti_ret"

# %%
df = df.sort_values("Date").reset_index(drop=True)

# compute indices based on original evaluation and test split
train_size = df.index[df["Date"] < "2014-02-01"][-1] + 1
val_end = df.index[df["Date"] <= "2020-01-01"][-1] + 1

# split using iloc 
train_data = df.iloc[:train_size]
val_data = df.iloc[train_size:val_end]
test_data = df.iloc[val_end:]

print(f"Train data length: {len(train_data)}")
print(f"Validation data length: {len(val_data)}")
print(f"Test data length: {len(test_data)}")
# Out:
# Train data length: 671
# Validation data length: 72
# Test data length: 72

# %%
# grid search over hyperparameters for the expanding window LSTM
param_grid_tiny = {
    "lookback": [2, 10],
    "dropout": [0.001, 0.1],
    "units": [50, 170],
    "epochs": [50, 100]
} 
param_combinations = list(itertools.product(
    param_grid_tiny["lookback"],
    param_grid_tiny["dropout"],
    param_grid_tiny["units"],
    param_grid_tiny["epochs"]
))

results_grid = []

for i, (lb, dr, units, ep) in enumerate(param_combinations, 1):
    print(f"\n[{i}/{len(param_combinations)}] Testing params:")
    print(f"lookback={lb}, dropout={dr}, units={units}, epochs={ep}")

    try:
        # cleanup before each parameter combination
        K.clear_session()
        tf.keras.backend.clear_session()
        gc.collect()

        val_forecasts = expanding_window_lstm_forecast(
            df=df,
            feature_cols=feature_cols,
            target_col=target_col,
            initial_train_size=train_size,
            end_idx=val_end,
            date_col="Date",
            lookback=lb,
            units=units,
            dropout=dr,
            epochs=ep,
            batch_size=32,
            verbose=0,
            scale=True,
            seed=42
        )

        if len(val_forecasts) == 0:
            print("No forecasts generated, skipping.")
            del val_forecasts
            gc.collect()
            continue

        mse = mean_squared_error(
            val_forecasts["actual"],
            val_forecasts["predicted"]
        )

        print(f"Validation MSE: {mse:.6f}")

        results_grid.append({
            "lookback": lb,
            "dropout": dr,
            "units": units,
            "epochs": ep,
            "mse": mse
        })

        # cleanup after each parameter combination
        del val_forecasts
        gc.collect()

    except Exception as e:
        print(f"Error: {e}")
        gc.collect()
        continue

results_grid = pd.DataFrame(results_grid).sort_values("mse").reset_index(drop=True)
# Out:
# [1/16] Testing params:
# lookback=2, dropout=0.001, units=50, epochs=50
# 2026-03-29 21:12:47.825867: W tensorflow/tsl/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_predict_function.<locals>.predict_function at 0x307ad1ab0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 6 calls to <function Model.make_predict_function.<locals>.predict_function at 0x305233d90> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Validation MSE: 0.051755
#
# [2/16] Testing params:
# lookback=2, dropout=0.001, units=50, epochs=100
# Validation MSE: 0.062654
#
# [3/16] Testing params:
# lookback=2, dropout=0.001, units=170, epochs=50
# Validation MSE: 0.050122
#
# [4/16] Testing params:
# lookback=2, dropout=0.001, units=170, epochs=100
# Validation MSE: 0.060725
#
# [5/16] Testing params:
# lookback=2, dropout=0.1, units=50, epochs=50
# Error: Graph execution error:
#
# Detected at node 'mul_8' defined at (most recent call last):
#     File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#       return _run_code(code, main_globals, None,
#     File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/runpy.py", line 86, in _run_code
#       exec(code, run_globals)
#     File "/Users/jasonlow/Library/Python/3.10/lib/python/site-packages/ipykernel_launcher.py", line 17, in <module>
#       app.launch_new_instance()
#     File "/Users/jasonlow/Library/Python/3.10/lib/python/site-packages/traitlets/config/application.py", line 1075, in launch_instance
#       app.start()
#     File "/Users/jasonlow/Library/Python/3.10/lib/python/site-packages/ipykernel/kernelapp.py", line 739, in start
#       self.io_loop.start()
#     File "/Users/jasonlow/Library/Python/3.10/lib/python/site-packages/tornado/platform/asyncio.py", line 205, in start
#       self.asyncio_loop.run_forever()
#     File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/asyncio/base_events.py", line 600, in run_forever
#       self._run_once()
#     File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/asyncio/base_events.py", line 1896, in _run_once
#       handle._run()
#     File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/asyncio/events.py", line 80, in _run
#       self._context.run(self._callback, *self._args)
#     File "/Users/jasonlow/Library/Python/3.10/lib/python/site-packages/ipykernel/kernelbase.py", line 542, in dispatch_queue
#       await self.process_one()
#     File "/Users/jasonlow/Library/Python/3.10/lib/python/site-packages/ipykernel/kernelbase.py", line 531, in process_one
#       await dispatch(*args)
#     File "/Users/jasonlow/Library/Python/3.10/lib/python/site-packages/ipykernel/kernelbase.py", line 437, in dispatch_shell
#       await result
#     File "/Users/jasonlow/Library/Python/3.10/lib/python/site-packages/ipykernel/ipkernel.py", line 359, in execute_request
#       await super().execute_request(stream, ident, parent)
#     File "/Users/jasonlow/Library/Python/3.10/lib/python/site-packages/ipykernel/kernelbase.py", line 775, in execute_request
#       reply_content = await reply_content
#     File "/Users/jasonlow/Library/Python/3.10/lib/python/site-packages/ipykernel/ipkernel.py", line 446, in do_execute
#       res = shell.run_cell(
#     File "/Users/jasonlow/Library/Python/3.10/lib/python/site-packages/ipykernel/zmqshell.py", line 549, in run_cell
#       return super().run_cell(*args, **kwargs)
#     File "/Users/jasonlow/Library/Python/3.10/lib/python/site-packages/IPython/core/interactiveshell.py", line 3051, in run_cell
#       result = self._run_cell(
#     File "/Users/jasonlow/Library/Python/3.10/lib/python/site-packages/IPython/core/interactiveshell.py", line 3106, in _run_cell
#       result = runner(coro)
#     File "/Users/jasonlow/Library/Python/3.10/lib/python/site-packages/IPython/core/async_helpers.py", line 129, in _pseudo_sync_runner
#       coro.send(None)
#     File "/Users/jasonlow/Library/Python/3.10/lib/python/site-packages/IPython/core/interactiveshell.py", line 3311, in run_cell_async
#       has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#     File "/Users/jasonlow/Library/Python/3.10/lib/python/site-packages/IPython/core/interactiveshell.py", line 3493, in run_ast_nodes
#       if await self.run_code(code, result, async_=asy):
#     File "/Users/jasonlow/Library/Python/3.10/lib/python/site-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#       exec(code_obj, self.user_global_ns, self.user_ns)
#     File "/var/folders/2h/gvrjdw1x6t766jgk66w62_tw0000gn/T/ipykernel_18405/3572460191.py", line 27, in <module>
#       val_forecasts = expanding_window_lstm_forecast(
#     File "/Users/jasonlow/Desktop/dse4101-project/lstm_src/my_lstm.py", line 204, in expanding_window_lstm_forecast
#       model.fit(
#     File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/keras/utils/traceback_utils.py", line 65, in error_handler
#       return fn(*args, **kwargs)
#     File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/keras/engine/training.py", line 1650, in fit
#       tmp_logs = self.train_function(iterator)
#     File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/keras/engine/training.py", line 1249, in train_function
#       return step_function(self, iterator)
#     File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/keras/engine/training.py", line 1233, in step_function
#       outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/keras/engine/training.py", line 1222, in run_step
#       outputs = model.train_step(data)
#     File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/keras/engine/training.py", line 1027, in train_step
#       self.optimizer.minimize(loss, self.trainable_variables, tape=tape)
#     File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/keras/optimizers/optimizer_experimental/optimizer.py", line 527, in minimize
#       self.apply_gradients(grads_and_vars)
#     File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/keras/optimizers/optimizer_experimental/optimizer.py", line 1140, in apply_gradients
#       return super().apply_gradients(grads_and_vars, name=name)
#     File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/keras/optimizers/optimizer_experimental/optimizer.py", line 634, in apply_gradients
#       iteration = self._internal_apply_gradients(grads_and_vars)
#     File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/keras/optimizers/optimizer_experimental/optimizer.py", line 1166, in _internal_apply_gradients
#       return tf.__internal__.distribute.interim.maybe_merge_call(
#     File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/keras/optimizers/optimizer_experimental/optimizer.py", line 1216, in _distributed_apply_gradients_fn
#       distribution.extended.update(
#     File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/keras/optimizers/optimizer_experimental/optimizer.py", line 1213, in apply_grad_to_update_var
#       return self._update_step(grad, var)
#     File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/keras/optimizers/optimizer_experimental/optimizer.py", line 224, in _update_step
#       self.update_step(gradient, variable)
#     File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/keras/optimizers/optimizer_experimental/adam.py", line 200, in update_step
#       variable.assign_sub((m * alpha) / (tf.sqrt(v) + self.epsilon))
# Node: 'mul_8'
# Incompatible shapes: [50,200] vs. [0]
# 	 [[{{node mul_8}}]] [Op:__inference_train_function_3914759]
#
# [6/16] Testing params:
# lookback=2, dropout=0.1, units=50, epochs=100
# Error: Graph execution error:
#
# Detected at node 'gradient_tape/mean_squared_error/Reshape_1' defined at (most recent call last):
#     File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#       return _run_code(code, main_globals, None,
#     File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/runpy.py", line 86, in _run_code
#       exec(code, run_globals)
#     File "/Users/jasonlow/Library/Python/3.10/lib/python/site-packages/ipykernel_launcher.py", line 17, in <module>
#       app.launch_new_instance()
#     File "/Users/jasonlow/Library/Python/3.10/lib/python/site-packages/traitlets/config/application.py", line 1075, in launch_instance
#       app.start()
#     File "/Users/jasonlow/Library/Python/3.10/lib/python/site-packages/ipykernel/kernelapp.py", line 739, in start
#       self.io_loop.start()
#     File "/Users/jasonlow/Library/Python/3.10/lib/python/site-packages/tornado/platform/asyncio.py", line 205, in start
#       self.asyncio_loop.run_forever()
#     File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/asyncio/base_events.py", line 600, in run_forever
#       self._run_once()
#     File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/asyncio/base_events.py", line 1896, in _run_once
#       handle._run()
#     File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/asyncio/events.py", line 80, in _run
#       self._context.run(self._callback, *self._args)
#     File "/Users/jasonlow/Library/Python/3.10/lib/python/site-packages/ipykernel/kernelbase.py", line 542, in dispatch_queue
#       await self.process_one()
#     File "/Users/jasonlow/Library/Python/3.10/lib/python/site-packages/ipykernel/kernelbase.py", line 531, in process_one
#       await dispatch(*args)
#     File "/Users/jasonlow/Library/Python/3.10/lib/python/site-packages/ipykernel/kernelbase.py", line 437, in dispatch_shell
#       await result
#     File "/Users/jasonlow/Library/Python/3.10/lib/python/site-packages/ipykernel/ipkernel.py", line 359, in execute_request
#       await super().execute_request(stream, ident, parent)
#     File "/Users/jasonlow/Library/Python/3.10/lib/python/site-packages/ipykernel/kernelbase.py", line 775, in execute_request
#       reply_content = await reply_content
#     File "/Users/jasonlow/Library/Python/3.10/lib/python/site-packages/ipykernel/ipkernel.py", line 446, in do_execute
#       res = shell.run_cell(
#     File "/Users/jasonlow/Library/Python/3.10/lib/python/site-packages/ipykernel/zmqshell.py", line 549, in run_cell
#       return super().run_cell(*args, **kwargs)
#     File "/Users/jasonlow/Library/Python/3.10/lib/python/site-packages/IPython/core/interactiveshell.py", line 3051, in run_cell
#       result = self._run_cell(
#     File "/Users/jasonlow/Library/Python/3.10/lib/python/site-packages/IPython/core/interactiveshell.py", line 3106, in _run_cell
#       result = runner(coro)
#     File "/Users/jasonlow/Library/Python/3.10/lib/python/site-packages/IPython/core/async_helpers.py", line 129, in _pseudo_sync_runner
#       coro.send(None)
#     File "/Users/jasonlow/Library/Python/3.10/lib/python/site-packages/IPython/core/interactiveshell.py", line 3311, in run_cell_async
#       has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#     File "/Users/jasonlow/Library/Python/3.10/lib/python/site-packages/IPython/core/interactiveshell.py", line 3493, in run_ast_nodes
#       if await self.run_code(code, result, async_=asy):
#     File "/Users/jasonlow/Library/Python/3.10/lib/python/site-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#       exec(code_obj, self.user_global_ns, self.user_ns)
#     File "/var/folders/2h/gvrjdw1x6t766jgk66w62_tw0000gn/T/ipykernel_18405/3572460191.py", line 27, in <module>
#       val_forecasts = expanding_window_lstm_forecast(
#     File "/Users/jasonlow/Desktop/dse4101-project/lstm_src/my_lstm.py", line 204, in expanding_window_lstm_forecast
#       model.fit(
#     File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/keras/utils/traceback_utils.py", line 65, in error_handler
#       return fn(*args, **kwargs)
#     File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/keras/engine/training.py", line 1650, in fit
#       tmp_logs = self.train_function(iterator)
#     File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/keras/engine/training.py", line 1249, in train_function
#       return step_function(self, iterator)
#     File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/keras/engine/training.py", line 1233, in step_function
#       outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/keras/engine/training.py", line 1222, in run_step
#       outputs = model.train_step(data)
#     File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/keras/engine/training.py", line 1027, in train_step
#       self.optimizer.minimize(loss, self.trainable_variables, tape=tape)
#     File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/keras/optimizers/optimizer_experimental/optimizer.py", line 526, in minimize
#       grads_and_vars = self.compute_gradients(loss, var_list, tape)
#     File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/keras/optimizers/optimizer_experimental/optimizer.py", line 259, in compute_gradients
#       grads = tape.gradient(loss, var_list)
# Node: 'gradient_tape/mean_squared_error/Reshape_1'
# Input to reshape is a tensor with 0 values, but the requested shape has 32
# 	 [[{{node gradient_tape/mean_squared_error/Reshape_1}}]] [Op:__inference_train_function_4107244]
#
# [7/16] Testing params:
# lookback=2, dropout=0.1, units=170, epochs=50
# Validation MSE: 0.044445
#
# [8/16] Testing params:
# lookback=2, dropout=0.1, units=170, epochs=100
# Error: Graph execution error:
#
# Detected at node 'gradient_tape/mean_squared_error/Reshape' defined at (most recent call last):
#     File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#       return _run_code(code, main_globals, None,
#     File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/runpy.py", line 86, in _run_code
#       exec(code, run_globals)
#     File "/Users/jasonlow/Library/Python/3.10/lib/python/site-packages/ipykernel_launcher.py", line 17, in <module>
#       app.launch_new_instance()
#     File "/Users/jasonlow/Library/Python/3.10/lib/python/site-packages/traitlets/config/application.py", line 1075, in launch_instance
#       app.start()
#     File "/Users/jasonlow/Library/Python/3.10/lib/python/site-packages/ipykernel/kernelapp.py", line 739, in start
#       self.io_loop.start()
#     File "/Users/jasonlow/Library/Python/3.10/lib/python/site-packages/tornado/platform/asyncio.py", line 205, in start
#       self.asyncio_loop.run_forever()
#     File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/asyncio/base_events.py", line 600, in run_forever
#       self._run_once()
#     File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/asyncio/base_events.py", line 1896, in _run_once
#       handle._run()
#     File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/asyncio/events.py", line 80, in _run
#       self._context.run(self._callback, *self._args)
#     File "/Users/jasonlow/Library/Python/3.10/lib/python/site-packages/ipykernel/kernelbase.py", line 542, in dispatch_queue
#       await self.process_one()
#     File "/Users/jasonlow/Library/Python/3.10/lib/python/site-packages/ipykernel/kernelbase.py", line 531, in process_one
#       await dispatch(*args)
#     File "/Users/jasonlow/Library/Python/3.10/lib/python/site-packages/ipykernel/kernelbase.py", line 437, in dispatch_shell
#       await result
#     File "/Users/jasonlow/Library/Python/3.10/lib/python/site-packages/ipykernel/ipkernel.py", line 359, in execute_request
#       await super().execute_request(stream, ident, parent)
#     File "/Users/jasonlow/Library/Python/3.10/lib/python/site-packages/ipykernel/kernelbase.py", line 775, in execute_request
#       reply_content = await reply_content
#     File "/Users/jasonlow/Library/Python/3.10/lib/python/site-packages/ipykernel/ipkernel.py", line 446, in do_execute
#       res = shell.run_cell(
#     File "/Users/jasonlow/Library/Python/3.10/lib/python/site-packages/ipykernel/zmqshell.py", line 549, in run_cell
#       return super().run_cell(*args, **kwargs)
#     File "/Users/jasonlow/Library/Python/3.10/lib/python/site-packages/IPython/core/interactiveshell.py", line 3051, in run_cell
#       result = self._run_cell(
#     File "/Users/jasonlow/Library/Python/3.10/lib/python/site-packages/IPython/core/interactiveshell.py", line 3106, in _run_cell
#       result = runner(coro)
#     File "/Users/jasonlow/Library/Python/3.10/lib/python/site-packages/IPython/core/async_helpers.py", line 129, in _pseudo_sync_runner
#       coro.send(None)
#     File "/Users/jasonlow/Library/Python/3.10/lib/python/site-packages/IPython/core/interactiveshell.py", line 3311, in run_cell_async
#       has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#     File "/Users/jasonlow/Library/Python/3.10/lib/python/site-packages/IPython/core/interactiveshell.py", line 3493, in run_ast_nodes
#       if await self.run_code(code, result, async_=asy):
#     File "/Users/jasonlow/Library/Python/3.10/lib/python/site-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#       exec(code_obj, self.user_global_ns, self.user_ns)
#     File "/var/folders/2h/gvrjdw1x6t766jgk66w62_tw0000gn/T/ipykernel_18405/3572460191.py", line 27, in <module>
#       val_forecasts = expanding_window_lstm_forecast(
#     File "/Users/jasonlow/Desktop/dse4101-project/lstm_src/my_lstm.py", line 204, in expanding_window_lstm_forecast
#       model.fit(
#     File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/keras/utils/traceback_utils.py", line 65, in error_handler
#       return fn(*args, **kwargs)
#     File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/keras/engine/training.py", line 1650, in fit
#       tmp_logs = self.train_function(iterator)
#     File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/keras/engine/training.py", line 1249, in train_function
#       return step_function(self, iterator)
#     File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/keras/engine/training.py", line 1233, in step_function
#       outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/keras/engine/training.py", line 1222, in run_step
#       outputs = model.train_step(data)
#     File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/keras/engine/training.py", line 1027, in train_step
#       self.optimizer.minimize(loss, self.trainable_variables, tape=tape)
#     File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/keras/optimizers/optimizer_experimental/optimizer.py", line 526, in minimize
#       grads_and_vars = self.compute_gradients(loss, var_list, tape)
#     File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/keras/optimizers/optimizer_experimental/optimizer.py", line 259, in compute_gradients
#       grads = tape.gradient(loss, var_list)
# Node: 'gradient_tape/mean_squared_error/Reshape'
# Input to reshape is a tensor with 0 values, but the requested shape has 32
# 	 [[{{node gradient_tape/mean_squared_error/Reshape}}]] [Op:__inference_train_function_5417454]
#
# [9/16] Testing params:
# lookback=10, dropout=0.001, units=50, epochs=50
# Validation MSE: 0.173775
#
# [10/16] Testing params:
# lookback=10, dropout=0.001, units=50, epochs=100
# Validation MSE: 0.436320
#
# [11/16] Testing params:
# lookback=10, dropout=0.001, units=170, epochs=50
# Validation MSE: 0.344615
#
# [12/16] Testing params:
# lookback=10, dropout=0.001, units=170, epochs=100
# Validation MSE: 0.528896
#
# [13/16] Testing params:
# lookback=10, dropout=0.1, units=50, epochs=50
# Validation MSE: 0.110276
#
# [14/16] Testing params:
# lookback=10, dropout=0.1, units=50, epochs=100
# Validation MSE: 0.240428
#
# [15/16] Testing params:
# lookback=10, dropout=0.1, units=170, epochs=50
# Validation MSE: 0.356990
#
# [16/16] Testing params:
# lookback=10, dropout=0.1, units=170, epochs=100
# Validation MSE: 0.506932

# %%
results_grid
# Out:
#     lookback  dropout  units  epochs       mse
# 0          2    0.100    170      50  0.044445
# 1          2    0.001    170      50  0.050122
# 2          2    0.001     50      50  0.051755
# 3          2    0.001    170     100  0.060725
# 4          2    0.001     50     100  0.062654
# 5         10    0.100     50      50  0.110276
# 6         10    0.001     50      50  0.173775
# 7         10    0.100     50     100  0.240428
# 8         10    0.001    170      50  0.344615
# 9         10    0.100    170      50  0.356990
# 10        10    0.001     50     100  0.436320
# 11        10    0.100    170     100  0.506932
# 12        10    0.001    170     100  0.528896

# %%
results_df = pd.DataFrame(results_grid)
results_df = results_df.sort_values("mse")

print(results_df.head())

best_params = results_df.iloc[0]
print(best_params)
# Out:
#    lookback  dropout  units  epochs       mse
# 0         2    0.100    170      50  0.044445
# 1         2    0.001    170      50  0.050122
# 2         2    0.001     50      50  0.051755
# 3         2    0.001    170     100  0.060725
# 4         2    0.001     50     100  0.062654
# lookback      2.000000
# dropout       0.100000
# units       170.000000
# epochs       50.000000
# mse           0.044445
# Name: 0, dtype: float64

# %% [markdown]
# # Out of sample testing

# %%
K.clear_session()
tf.keras.backend.clear_session()
gc.collect()
# Out:
# 56801

# %%
best_params["lookback"], best_params["dropout"], best_params["units"], best_params["epochs"]
# Out:
# (2.0, 0.1, 170.0, 50.0)

# %%
test_results = expanding_window_lstm_forecast(
    df=df,
    feature_cols=feature_cols,
    target_col=target_col,
    initial_train_size=val_end,  
    end_idx=len(df),    
    date_col="Date",        
    lookback=int(best_params["lookback"]),
    units=int(best_params["units"]),
    dropout=float(best_params["dropout"]),
    epochs=int(best_params["epochs"]),
    batch_size=32,
    verbose=0,
    scale=True,
    seed=42
)

test_mse = mean_squared_error(
    test_results["actual"],
    test_results["predicted"]
)

test_mape = mean_absolute_percentage_error(
    test_results["actual"],
    test_results["predicted"]
)

test_r2 = r2_score(
    test_results["actual"],
    test_results["predicted"]
)

print("Test MSE:", test_mse)
print("Test MAPE:", test_mape)
print("Test R²:", test_r2)
# Out:
# train_df length: 743
# X_train shape: (741, 2, 2)
# y_train shape: (741,)
# lookback: 2
# train_df length: 744
# X_train shape: (742, 2, 2)
# y_train shape: (742,)
# lookback: 2
# train_df length: 745
# X_train shape: (743, 2, 2)
# y_train shape: (743,)
# lookback: 2
# train_df length: 746
# X_train shape: (744, 2, 2)
# y_train shape: (744,)
# lookback: 2
# train_df length: 747
# X_train shape: (745, 2, 2)
# y_train shape: (745,)
# lookback: 2
# train_df length: 748
# X_train shape: (746, 2, 2)
# y_train shape: (746,)
# lookback: 2
# train_df length: 749
# X_train shape: (747, 2, 2)
# y_train shape: (747,)
# lookback: 2
# train_df length: 750
# X_train shape: (748, 2, 2)
# y_train shape: (748,)
# lookback: 2
# train_df length: 751
# X_train shape: (749, 2, 2)
# y_train shape: (749,)
# lookback: 2
# train_df length: 752
# X_train shape: (750, 2, 2)
# y_train shape: (750,)
# lookback: 2
# train_df length: 753
# X_train shape: (751, 2, 2)
# y_train shape: (751,)
# lookback: 2
# train_df length: 754
# X_train shape: (752, 2, 2)
# y_train shape: (752,)
# lookback: 2
# train_df length: 755
# X_train shape: (753, 2, 2)
# y_train shape: (753,)
# lookback: 2
# train_df length: 756
# X_train shape: (754, 2, 2)
# y_train shape: (754,)
# lookback: 2
# train_df length: 757
# X_train shape: (755, 2, 2)
# y_train shape: (755,)
# lookback: 2
# train_df length: 758
# X_train shape: (756, 2, 2)
# y_train shape: (756,)
# lookback: 2
# train_df length: 759
# X_train shape: (757, 2, 2)
# y_train shape: (757,)
# lookback: 2
# train_df length: 760
# X_train shape: (758, 2, 2)
# y_train shape: (758,)
# lookback: 2
# train_df length: 761
# X_train shape: (759, 2, 2)
# y_train shape: (759,)
# lookback: 2
# train_df length: 762
# X_train shape: (760, 2, 2)
# y_train shape: (760,)
# lookback: 2
# train_df length: 763
# X_train shape: (761, 2, 2)
# y_train shape: (761,)
# lookback: 2
# train_df length: 764
# X_train shape: (762, 2, 2)
# y_train shape: (762,)
# lookback: 2
# train_df length: 765
# X_train shape: (763, 2, 2)
# y_train shape: (763,)
# lookback: 2
# train_df length: 766
# X_train shape: (764, 2, 2)
# y_train shape: (764,)
# lookback: 2
# train_df length: 767
# X_train shape: (765, 2, 2)
# y_train shape: (765,)
# lookback: 2
# train_df length: 768
# X_train shape: (766, 2, 2)
# y_train shape: (766,)
# lookback: 2
# train_df length: 769
# X_train shape: (767, 2, 2)
# y_train shape: (767,)
# lookback: 2
# train_df length: 770
# X_train shape: (768, 2, 2)
# y_train shape: (768,)
# lookback: 2
# train_df length: 771
# X_train shape: (769, 2, 2)
# y_train shape: (769,)
# lookback: 2
# train_df length: 772
# X_train shape: (770, 2, 2)
# y_train shape: (770,)
# lookback: 2
# train_df length: 773
# X_train shape: (771, 2, 2)
# y_train shape: (771,)
# lookback: 2
# train_df length: 774
# X_train shape: (772, 2, 2)
# y_train shape: (772,)
# lookback: 2
# train_df length: 775
# X_train shape: (773, 2, 2)
# y_train shape: (773,)
# lookback: 2
# train_df length: 776
# X_train shape: (774, 2, 2)
# y_train shape: (774,)
# lookback: 2
# train_df length: 777
# X_train shape: (775, 2, 2)
# y_train shape: (775,)
# lookback: 2
# train_df length: 778
# X_train shape: (776, 2, 2)
# y_train shape: (776,)
# lookback: 2
# train_df length: 779
# X_train shape: (777, 2, 2)
# y_train shape: (777,)
# lookback: 2
# train_df length: 780
# X_train shape: (778, 2, 2)
# y_train shape: (778,)
# lookback: 2
# train_df length: 781
# X_train shape: (779, 2, 2)
# y_train shape: (779,)
# lookback: 2
# train_df length: 782
# X_train shape: (780, 2, 2)
# y_train shape: (780,)
# lookback: 2
# train_df length: 783
# X_train shape: (781, 2, 2)
# y_train shape: (781,)
# lookback: 2
# train_df length: 784
# X_train shape: (782, 2, 2)
# y_train shape: (782,)
# lookback: 2
# train_df length: 785
# X_train shape: (783, 2, 2)
# y_train shape: (783,)
# lookback: 2
# train_df length: 786
# X_train shape: (784, 2, 2)
# y_train shape: (784,)
# lookback: 2
# train_df length: 787
# X_train shape: (785, 2, 2)
# y_train shape: (785,)
# lookback: 2
# train_df length: 788
# X_train shape: (786, 2, 2)
# y_train shape: (786,)
# lookback: 2
# train_df length: 789
# X_train shape: (787, 2, 2)
# y_train shape: (787,)
# lookback: 2
# train_df length: 790
# X_train shape: (788, 2, 2)
# y_train shape: (788,)
# lookback: 2
# train_df length: 791
# X_train shape: (789, 2, 2)
# y_train shape: (789,)
# lookback: 2
# train_df length: 792
# X_train shape: (790, 2, 2)
# y_train shape: (790,)
# lookback: 2
# train_df length: 793
# X_train shape: (791, 2, 2)
# y_train shape: (791,)
# lookback: 2
# train_df length: 794
# X_train shape: (792, 2, 2)
# y_train shape: (792,)
# lookback: 2
# train_df length: 795
# X_train shape: (793, 2, 2)
# y_train shape: (793,)
# lookback: 2
# train_df length: 796
# X_train shape: (794, 2, 2)
# y_train shape: (794,)
# lookback: 2
# train_df length: 797
# X_train shape: (795, 2, 2)
# y_train shape: (795,)
# lookback: 2
# train_df length: 798
# X_train shape: (796, 2, 2)
# y_train shape: (796,)
# lookback: 2
# train_df length: 799
# X_train shape: (797, 2, 2)
# y_train shape: (797,)
# lookback: 2
# train_df length: 800
# X_train shape: (798, 2, 2)
# y_train shape: (798,)
# lookback: 2
# train_df length: 801
# X_train shape: (799, 2, 2)
# y_train shape: (799,)
# lookback: 2
# train_df length: 802
# X_train shape: (800, 2, 2)
# y_train shape: (800,)
# lookback: 2
# train_df length: 803
# X_train shape: (801, 2, 2)
# y_train shape: (801,)
# lookback: 2
# train_df length: 804
# X_train shape: (802, 2, 2)
# y_train shape: (802,)
# lookback: 2
# train_df length: 805
# X_train shape: (803, 2, 2)
# y_train shape: (803,)
# lookback: 2
# train_df length: 806
# X_train shape: (804, 2, 2)
# y_train shape: (804,)
# lookback: 2
# train_df length: 807
# X_train shape: (805, 2, 2)
# y_train shape: (805,)
# lookback: 2
# train_df length: 808
# X_train shape: (806, 2, 2)
# y_train shape: (806,)
# lookback: 2
# train_df length: 809
# X_train shape: (807, 2, 2)
# y_train shape: (807,)
# lookback: 2
# train_df length: 810
# X_train shape: (808, 2, 2)
# y_train shape: (808,)
# lookback: 2
# train_df length: 811
# X_train shape: (809, 2, 2)
# y_train shape: (809,)
# lookback: 2
# train_df length: 812
# X_train shape: (810, 2, 2)
# y_train shape: (810,)
# lookback: 2
# train_df length: 813
# X_train shape: (811, 2, 2)
# y_train shape: (811,)
# lookback: 2
# train_df length: 814
# X_train shape: (812, 2, 2)
# y_train shape: (812,)
# lookback: 2
# Test MSE: 0.44454939680921257
# Test MAPE: 7.133386333482012
# Test R²: -22.46153040469129

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,5))
plt.plot(test_results['Date'], test_results["actual"], label="Actual")
plt.plot(test_results['Date'], test_results["predicted"], label="Predicted")
plt.legend()
plt.title("Out-of-sample Forecast for LSTM-VAETIMEGAN (With all covariates)")
plt.show()

# %%
# save results to csv
test_results.to_csv('results/lstm-1-vaetimegan_results.csv', index = False)
